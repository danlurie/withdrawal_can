# %% [markdown]
# ## Withdrawal Network - Unthresholded

# %%
import numpy as np
import pandas as pd
import networkx as nx
import bct as bct
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Prepare the network for analysis.

# %% [markdown]
# Load the withdrawal correlation matrix.

# %%
withdrawal_df = pd.read_csv('../../data/cFosCAN_alcohol_withdrawal_orig_20180326.csv')

# %% [markdown]
# Set the index to the region labels.

# %%
withdrawal_df = withdrawal_df.set_index('Unnamed: 0')

# %% [markdown]
# Sort regions alphabetically.

# %%
withdrawal_df = withdrawal_df.sort_index()
withdrawal_df = withdrawal_df.sort_index(axis=1)

# %%
withdrawal_mat = withdrawal_df.as_matrix()

# %% [markdown]
# Zero-out the diagonal and save the matrix for analysis in MATLAB.

# %%
np.fill_diagonal(withdrawal_mat, 0)

# %%
np.savetxt('/home/despoB/dlurie/Projects/withdrawal_CAN/data/cFosCAN_alcohol_withdrawal_mat_20180526.csv', withdrawal_mat)

# %% [markdown]
# Plotting functions do not play nice with negative edges or dense graphs, so we remove those when laying out the plot.

# %%
withdrawal_mat_po = withdrawal_mat.copy()

# %%
withdrawal_mat_po[withdrawal_mat_po < 0.80] = 0

# %%
G_po = nx.from_numpy_matrix(withdrawal_mat_po)

# %% [markdown]
# #### Centrality (node strength)

# %%
node_strength = bct.degree.strengths_und_sign(withdrawal_mat)

# %%
fig, ax = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14,5))
g = nx.draw_kamada_kawai(G_po, node_color=node_strength[0], node_size=150, cmap=plt.cm.viridis, ax=ax[0])
g = nx.draw_kamada_kawai(G_po, node_color=node_strength[1], node_size=150, cmap=plt.cm.viridis_r, ax=ax[1])
g = ax[0].set_title('Positive Edge Centrality', fontsize=16)
g = ax[1].set_title('Negative Edge Centrality', fontsize=16)

# %% [markdown]
# ### Visualize the Louvain partition and nodal metrics.
# These were calculated using the `run_louvain.m` Matlab script and gamma=1.0.

# %%
reordered_matrix = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_ReorderedMatrix.txt')

# %%
reordered_matrix = reordered_matrix.reshape(withdrawal_mat.shape)

# %%
partition = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_GraphPartition.txt')

# %%
fig, ax = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14,5))
g = sns.heatmap(reordered_matrix, xticklabels=False, yticklabels=False, ax=ax[0], )
g = nx.draw_kamada_kawai(G_po, node_color=partition, node_size=150, cmap=plt.cm.Paired, ax=ax[1])
g = ax[0].set_title('Co-Activation Matrix Ordered by Module', fontsize=16)
g = ax[1].set_title('Graph Partition', fontsize=16)

# %% [markdown]
# ### Within-Module Degree (z-scored)

# %%
wmdz = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_WMDz.txt')

# %%
nx.draw_kamada_kawai(G_po, node_color=wmdz, node_size=150, cmap=plt.cm.RdBu_r)

# %% [markdown]
# ### Participation Coefficient

# %%
pc_pos = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_PC_pos.txt')

# %%
pc_neg = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_PC_neg.txt')

# %%
fig, ax = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14,5))
nx.draw_kamada_kawai(G_po, node_color=pc_pos, node_size=150, cmap=plt.cm.viridis, ax=ax[0])
nx.draw_kamada_kawai(G_po, node_color=pc_neg, node_size=150, cmap=plt.cm.viridis, ax=ax[1])
g = ax[0].set_title('Positive Edge PC', fontsize=16)
g = ax[1].set_title('Negative Edge PC', fontsize=16)

# %% [markdown]
# Combine all our results into a single spreadsheet.

# %%
combined_df = pd.DataFrame(np.array([node_strength[0], node_strength[1], partition, pc_pos, pc_neg, wmdz]).T,
                           columns=['centrality_pos', 'centrality_neg', 'partition', 'pc_pos', 'pc_neg', 'wmdz'])

# %%
combined_df = combined_df.set_index(withdrawal_df.index)

# %%
combined_df.index.names = ['Region']

# %% [markdown]
# Save the combined spreadsheet to disk.

# %%
combined_df.to_csv('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma1.0_combined_results.csv', sep=',')

# %% [markdown]
# ## Resolution Parameter = 2.0
# These were calculated using the `run_louvain.m` Matlab script and gamma=2.0.

# %%
reordered_matrix = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_ReorderedMatrix.txt')

# %%
reordered_matrix = reordered_matrix.reshape(withdrawal_mat.shape)

# %%
partition = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_GraphPartition.txt')

# %%
fig, ax = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14,5))
g = sns.heatmap(reordered_matrix, xticklabels=False, yticklabels=False, ax=ax[0], )
g = nx.draw_kamada_kawai(G_po, node_color=partition, node_size=150, cmap=plt.cm.Paired, ax=ax[1])
g = ax[0].set_title('Co-Activation Matrix Ordered by Module', fontsize=16)
g = ax[1].set_title('Graph Partition', fontsize=16)

# %% [markdown]
# ### Within-Module Degree (z-scored)

# %%
wmdz = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_WMDz.txt')

# %%
nx.draw_kamada_kawai(G_po, node_color=wmdz, node_size=150, cmap=plt.cm.RdBu_r)

# %% [markdown]
# ### Participation Coefficient

# %%
pc_pos = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_PC_pos.txt')

# %%
pc_neg = np.genfromtxt('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_PC_neg.txt')

# %%
fig, ax = plt.subplots(1, 2, sharex=False, sharey=False, figsize=(14,5))
nx.draw_kamada_kawai(G_po, node_color=pc_pos, node_size=150, cmap=plt.cm.viridis, ax=ax[0])
nx.draw_kamada_kawai(G_po, node_color=pc_neg, node_size=150, cmap=plt.cm.viridis, ax=ax[1])
g = ax[0].set_title('Positive Edge PC', fontsize=16)
g = ax[1].set_title('Negative Edge PC', fontsize=16)

# %% [markdown]
# Combine all our results into a single spreadsheet.

# %%
combined_df = pd.DataFrame(np.array([node_strength[0], node_strength[1], partition, pc_pos, pc_neg, wmdz]).T,
                           columns=['centrality_pos', 'centrality_neg', 'partition', 'pc_pos', 'pc_neg', 'wmdz'])

# %%
combined_df = combined_df.set_index(withdrawal_df.index)

# %%
combined_df.index.names = ['Region']

# %% [markdown]
# Save the combined spreadsheet to disk.

# %%
combined_df.to_csv('/home/despoB/dlurie/Projects/withdrawal_CAN/results/withdrawal_nothresh/gamma2.0_combined_results.csv', sep=',')
